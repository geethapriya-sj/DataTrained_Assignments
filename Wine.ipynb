# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',)
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
columns = ['Wine_Quality','Alcohol','Malic_acid','Ash','Alcalinity_of_ash','Magnesium','Total_phenols','Flavanoids',
          'Nonflavanoid_phenols','Proanthocyanins','Color_intensity','Hue','OD280/OD315_of_diluted_wines','Proline'
          ]
df.columns = columns

# %%
df.head()
# Out:
#    Wine_Quality  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0             1    13.20        1.78  2.14               11.2        100
# 1             1    13.16        2.36  2.67               18.6        101
# 2             1    14.37        1.95  2.50               16.8        113
# 3             1    13.24        2.59  2.87               21.0        118
# 4             1    14.20        1.76  2.45               15.2        112
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color_intensity   Hue  OD280/OD315_of_diluted_wines  Proline
# ...

# %%
df.describe()
# Out:
#        Wine_Quality     Alcohol  Malic_acid         Ash  Alcalinity_of_ash  \
# count    177.000000  177.000000  177.000000  177.000000         177.000000
# mean       1.943503   12.993672    2.339887    2.366158          19.516949
# std        0.773991    0.808808    1.119314    0.275080           3.336071
# min        1.000000   11.030000    0.740000    1.360000          10.600000
# 25%        1.000000   12.360000    1.600000    2.210000          17.200000
# 50%        2.000000   13.050000    1.870000    2.360000          19.500000
# 75%        3.000000   13.670000    3.100000    2.560000          21.500000
# max        3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
# Wine_Quality                    177 non-null int64
# Alcohol                         177 non-null float64
# Malic_acid                      177 non-null float64
# Ash                             177 non-null float64
# Alcalinity_of_ash               177 non-null float64
# Magnesium                       177 non-null int64
# Total_phenols                   177 non-null float64
# Flavanoids                      177 non-null float64
# Nonflavanoid_phenols            177 non-null float64
# Proanthocyanins                 177 non-null float64
# Color_intensity                 177 non-null float64
# Hue                             177 non-null float64
# OD280/OD315_of_diluted_wines    177 non-null float64
# Proline                         177 non-null int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
sns.catplot(x='Wine_Quality',data=df,kind='count')

# %%
plt.figure(figsize=(13,5))
sns.heatmap(df.corr(),annot=True)

# %%
len(df.columns.values)
# Out:
# 14

# %%
plt.figure(figsize=(10,15))
for i,col in enumerate(list(df.columns.values)):
    plt.subplot(7,2,i+1)
    df.boxplot(col)
    plt.grid()
    plt.tight_layout()

# %%
plt.figure(figsize=(10,15))
for i,col in enumerate(list(df.columns.values)):
    plt.subplot(7,2,i+1)
    sns.distplot(df[col],color='blue',kde=True)
    plt.grid()
    plt.tight_layout()

# %%
sns.pairplot(data=df)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold = 3
print(np.where(z>threshold))
# Out:
# (array([ 24,  58,  68,  72,  94, 109, 114, 120, 120, 122, 157], dtype=int64), array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (167, 14)

# %%
df.shape
# Out:
# (177, 14)

# %%
plt.figure(figsize=(10,15))
for i,col in enumerate(list(df_new.columns.values)):
    plt.subplot(7,2,i+1)
    df_new.boxplot(col)
    plt.grid()
    plt.tight_layout()

# %%
X = df_new.drop(columns=['Wine_Qualit`y'],axis=1)
y = df_new['Wine_Quality']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import Lasso,LogisticRegression,LinearRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
def find_best_model_usingGrdSearchcv(X,y):
    algos={
        'Lasso':{
            'model':Lasso(),
             'params':{
                 'alpha':[1,2],
                 'selection':['random','cyclic']
             }
        },
        'RandomForestClassifier':{
            'model':RandomForestClassifier(),
             'params':{
                 'criterion':['gini','entropy'],
                 'random_state':[42],
                 'min_samples_leaf':[10,20,30]
             }
        },
        'LogisticRegression':{
            'model':LogisticRegression(),
             'params':{
                 'C':[100,200,300,400,500]
             }
        },
        'DecisionTree':{
            'model':DecisionTreeRegressor(),
             'params':{
                 'criterion':['mse','friedman_mse'],
                 'splitter':['best','random']
                
             }    
        },
        'Linear_regression':{
            'model':LinearRegression(),
             'params':{
                 'normalize':[True,False]
             }
            
        },
    }
    scores=[]
    cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name,config in algos.items():
        print(algo_name)
        gs = GridSearchCV(config['model'],config['params'],cv=cv,return_train_score=False)
        gs.fit(X,y)
        scores.append({
        'model':algo_name,
        'best_Score':gs.best_score_,
        'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_Score','best_params'])

# %%
find_best_model_usingGrdSearchcv(X_train,y_train)
# Out:
# Lasso
# RandomForestClassifier
# LogisticRegression
# DecisionTree
# Linear_regression
#                     model  best_Score  \
# 0                   Lasso    0.157718
# 1  RandomForestClassifier    0.930435
# 2      LogisticRegression    0.930435
# 3            DecisionTree    0.873481
# 4       Linear_regression    0.818061
#
#                                          best_params
# 0                {'alpha': 2, 'selection': 'random'}
# 1  {'criterion': 'gini', 'min_samples_leaf': 10, ...
# 2                                         {'C': 200}
# 3  {'criterion': 'friedman_mse', 'splitter': 'ran...
# 4                               {'normalize': False}

# %%
model_l = LogisticRegression(C=200)
model_l.fit(X_train,y_train)
model_l.score(X_test,y_test)
# Out:
# 0.9107142857142857

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score

# %%
predict = model_l.predict(X_test)

# %%
confusion_matrix(y_test, predict)
# Out:
# array([[21,  0,  0],
#        [ 1, 18,  3],
#        [ 0,  1, 12]], dtype=int64)

# %%
accuracy_score(y_test, predict)
# Out:
# 0.9107142857142857

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.98        21
#            2       0.95      0.82      0.88        22
#            3       0.80      0.92      0.86        13
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.91      0.90        56
# weighted avg       0.92      0.91      0.91        56
